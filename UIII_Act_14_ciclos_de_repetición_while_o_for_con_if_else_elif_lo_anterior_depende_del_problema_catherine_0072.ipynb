# %% [markdown]
# <a href="https://colab.research.google.com/github/catherinerascon128/UIII-Act-14-ciclos-de-repetici-n-while-o-for-con-if-else-elif-lo-anterior-depende-del-problema-0072/blob/main/UIII_Act_14_ciclos_de_repetici%C3%B3n_while_o_for_con_if_else_elif_lo_anterior_depende_del_problema_catherine_0072.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### catherine rascon NL = 30 Fecha 28/05/26
# #### especialidad inteligencia artificial
# #### nombre del plantel cbtis No 128,
# #### Submodulo 2 Elabora proyectos de programación lógica,
# #### docente: Eliseo Nava

# %% [markdown]
# ### REDACCION DEL PROBLEMA ✈
# #### Algoritmo que dibuje un rombo de asteriscos de altura impar
# info
# ![texto del vínculo](https://raw.githubusercontent.com/catherinerascon128/UIII-Act-14-ciclos-de-repetici-n-while-o-for-con-if-else-elif-lo-anterior-depende-del-problema-0072/refs/heads/main/infoasterisco.png)

# %%
# Programa que dibuja un rombo de asteriscos
# La altura debe ser un número impar

altura = int(input("Ingresa la altura impar del rombo: "))

if altura % 2 == 0:
    print("La altura debe ser un número impar.")
else:
    mitad = altura // 2

    # Parte superior del rombo
    for i in range(mitad + 1):
        espacios = mitad - i
        asteriscos = 2 * i + 1

        print(" " * espacios + "*" * asteriscos)

    # Parte inferior del rombo
    for i in range(mitad - 1, -1, -1):
        espacios = mitad - i
        asteriscos = 2 * i + 1

        print(" " * espacios + "*" * asteriscos)
# Out:
# Ingresa la altura impar del rombo: 13
#       *
#      ***
#     *****
#    *******
#   *********
#  ***********
# *************
#  ***********
#   *********
#    *******
#     *****
#      ***
#       *
